# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import openpyxl
from pandas_profiling import ProfileReport

# %%
Odf = pd.read_excel('observedDataset.xlsx', index_col=0)

# %%
Odf.head()
# Out:
#    stationID  Days  observedTempMax  observedTempMin  observedHumidity  \
# 0      10120     1        23.182051        10.735897         77.586207
# 1      10120     2        22.997436        10.738462         78.655172
# 2      10120     3        22.276923        10.566667         80.551724
# 3      10120     4        22.115385        10.712821         79.862069
# 4      10120     5        22.325641        10.274359         79.758621
#
#    observedPressure  observedWind  observedRainfall
# 0       1016.255172      3.968966          0.034483
# 1       1016.424138      4.017241          0.310345
# 2       1016.227586      4.306897          0.448276
# 3       1016.027586      4.234483          0.758621
# 4       1015.627586      4.434483          0.034483

# %%
Odf.loc[Odf['observedRainfall'] <0.5, 'observedRainfallcatagorical'] = '0'
Odf.loc[Odf['observedRainfall'] >=0.5, 'observedRainfallcatagorical'] = '1'
Odf.head()
# Out:
#    stationID  Days  observedTempMax  observedTempMin  observedHumidity  \
# 0      10120     1        23.182051        10.735897         77.586207
# 1      10120     2        22.997436        10.738462         78.655172
# 2      10120     3        22.276923        10.566667         80.551724
# 3      10120     4        22.115385        10.712821         79.862069
# 4      10120     5        22.325641        10.274359         79.758621
#
#    observedPressure  observedWind  observedRainfall  \
# 0       1016.255172      3.968966          0.034483
# 1       1016.424138      4.017241          0.310345
# 2       1016.227586      4.306897          0.448276
# 3       1016.027586      4.234483          0.758621
# 4       1015.627586      4.434483          0.034483
#
#   observedRainfallcatagorical
# 0                           0
# 1                           0
# 2                           0
# 3                           1
# 4                           0

# %%
Odf.drop("observedRainfall", axis=1, inplace=True)

# %%
Odf.head()
# Out:
#    stationID  Days  observedTempMax  observedTempMin  observedHumidity  \
# 0      10120     1        23.182051        10.735897         77.586207
# 1      10120     2        22.997436        10.738462         78.655172
# 2      10120     3        22.276923        10.566667         80.551724
# 3      10120     4        22.115385        10.712821         79.862069
# 4      10120     5        22.325641        10.274359         79.758621
#
#    observedPressure  observedWind observedRainfallcatagorical
# 0       1016.255172      3.968966                           0
# 1       1016.424138      4.017241                           0
# 2       1016.227586      4.306897                           0
# 3       1016.027586      4.234483                           1
# 4       1015.627586      4.434483                           0

# %%
Odf.columns
# Out:
# Index(['stationID', 'Days', 'observedTempMax', 'observedTempMin',
#        'observedHumidity', 'observedPressure', 'observedWind',
#        'observedRainfallcatagorical'],
#       dtype='object')

# %%
Odf.to_csv('observedDataset1.csv')

# %%
Odf["observedWind"].min()
# Out:
# 0.0

# %%
Odf.describe().T
# Out:
#                     count          mean           std           min  \
# stationID         12838.0  15817.085995  10755.024541  10120.000000
# Days              12838.0  183.131407    105.838279    1.000000
# observedTempMax   12838.0  30.637295     2.752837      21.420690
# observedTempMin   12838.0  21.326764     4.904168      9.252632
# observedHumidity  12808.0  79.906114     6.131441      56.692308
# observedPressure  12810.0  1008.018912   5.452239      974.853846
# observedWind      12808.0  3.202191      1.336710      0.000000
#
#                            25%           50%           75%           max
# stationID         11111.000000  11706.000000  11929.000000  41977.000000
# Days              91.000000     183.000000    275.000000    366.000000
# observedTempMax   29.149396     31.472662     32.445666     36.854839
# observedTempMin   17.046795     23.530769     25.517024     27.170968
# observedHumidity  76.102564     80.410256     84.897436     97.000000
# ...

# %%
Odf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12838 entries, 0 to 12837
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   stationID                    12838 non-null  int64
#  1   Days                         12838 non-null  int64
#  2   observedTempMax              12838 non-null  float64
#  3   observedTempMin              12838 non-null  float64
#  4   observedHumidity             12808 non-null  float64
#  5   observedPressure             12810 non-null  float64
#  6   observedWind                 12808 non-null  float64
#  7   observedRainfallcatagorical  12810 non-null  object
# dtypes: float64(5), int64(2), object(1)
# memory usage: 902.7+ KB

# %%
Odf.isna().sum()
# Out:
# stationID                      0
# Days                           0
# observedTempMax                0
# observedTempMin                0
# observedHumidity               30
# observedPressure               28
# observedWind                   30
# observedRainfallcatagorical    28
# dtype: int64

# %%
#prof = ProfileReport(Odf)
#prof.to_file(output_file='WeatherProfileReport.html')

# %%
Odf.head()
# Out:
#    stationID  Days  observedTempMax  observedTempMin  observedHumidity  \
# 0  10120      1     23.182051        10.735897        77.586207
# 1  10120      2     22.997436        10.738462        78.655172
# 2  10120      3     22.276923        10.566667        80.551724
# 3  10120      4     22.115385        10.712821        79.862069
# 4  10120      5     22.325641        10.274359        79.758621
#
#    observedPressure  observedWind observedRainfallcatagorical
# 0  1016.255172       3.968966      0
# 1  1016.424138       4.017241      0
# 2  1016.227586       4.306897      0
# 3  1016.027586       4.234483      1
# 4  1015.627586       4.434483      0

# %%
data['Precip Type'].value_counts()

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None) 

pd.set_option('display.max_colwidth',0)  
print(Odf)
# Out:
#        stationID  Days  observedTempMax  observedTempMin  observedHumidity  \
# 0      10120      1     23.182051        10.735897        77.586207
# 1      10120      2     22.997436        10.738462        78.655172
# 2      10120      3     22.276923        10.566667        80.551724
# 3      10120      4     22.115385        10.712821        79.862069
# 4      10120      5     22.325641        10.274359        79.758621
# 5      10120      6     22.648718        10.028205        79.000000
# 6      10120      7     22.512821        10.310256        79.655172
# 7      10120      8     22.533333        10.182051        78.931034
# 8      10120      9     22.092308        10.494872        80.034483
# 9      10120      10    21.917949        9.892308         79.413793
# 10     10120      11    22.105128        10.010256        80.241379
# 11     10120      12    22.030769        10.043590        79.586207
# 12     10120      13    22.323077        9.679487         78.827586
# ...
